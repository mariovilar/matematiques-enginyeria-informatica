# %% [markdown]
# # Naive Bayes i Classificació
#
# ### Instruccions
#
# + L'exàmen consta de tres preguntes.
# + Per a poder contestar les preguntes, heu de descarregar el fitxer `cyberbullying_tweets.csv` del campus virtual.
# + Podeu usar també les funcions del notebook de la vostra pràctica.

# %% [markdown]
# ## 1. Lectura de les dades

# %%
import pandas as pd
import numpy as np
import re
import sklearn

# %%
df = pd.read_csv('cyberbullying_tweets.csv')
df
# Out:
#                                               tweet_text cyberbullying_type
# 0      In other words #katandandre, your food was cra...  not_cyberbullying
# 1      Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2      @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3      @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4      @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# ...                                                  ...                ...
# 47687  Black ppl aren't expected to do anything, depe...          ethnicity
# 47688  Turner did not withhold his disappointment. Tu...          ethnicity
# 47689  I swear to God. This dumb nigger bitch. I have...          ethnicity
# 47690  Yea fuck you RT @therealexel: IF YOURE A NIGGE...          ethnicity
# 47691  Bro. U gotta chill RT @CHILLShrammy: Dog FUCK ...          ethnicity
#
# [47692 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

df_tweets_train, df_tweets_test = train_test_split(df, test_size=0.2)

# %% [markdown]
# ## Exercici 1 (2 punts)
# Escriu la funció ``get_predictions_datafram`` que retorni un dataframe amb 3 columnes: el tweet original, la categoria real i la categoria predita.

# %%
def get_predictions_dataframe(df_test, df_train, top_words, probs):
    """
    :param df_test: DataFrame with the test tweets and associated information
    :param df_train: DataFrame with the training tweets and associated information
    :param top_words: Dictionary of top words for each category
    :param probs: Dictionary of conditional probabilities for each category
    :return: DataFrame with columns 'tweet', 'real_category', 'predicted_category'
    """
    
    #El teu codi aquí

    

# Exemple:
# Suposant que df_tweets_test, df_tweets_train, top_words i probs ja estan definits.
probs = naive_bayes_learn(df_tweets_train, feat_train)
predictions_df = get_predictions_dataframe(df_tweets_test, df_tweets_train, top_words, probs)
print(predictions_df.head())

# %% [markdown]
# ## Exercici 2 (5 punts)
# Fent servir la funció anterior, calcula amb la funció ``get_category_accuracies`` l'accuracy de cada categoria.
# Retorna un diccionari del tipus ``{"category_1": <accuracy>, "category_2", <accuracy> ...}``

# %%
def get_category_accuracies(df_test, df_train, top_words, probs):
    """
    :param df_test: DataFrame with the test tweets and associated information
    :param df_train: DataFrame with the training tweets and associated information
    :param top_words: Dictionary of top words for each category
    :param probs: Dictionary of conditional probabilities for each category
    :return: Dictionary with accuracy for each category
    """
    #El teu codi aquí

# Exemple:
# Suposant que df_tweets_test, df_tweets_train, top_words i probs ja estan definits.
category_accuracies = get_category_accuracies(df_tweets_test, df_tweets_train, top_words, probs)
print(category_accuracies)

# %% [markdown]
# ## Exercici 3 (3 punts)
# Explica per què és important balancejar les dades en una tasca de classificació si hi ha classes amb molts menys exemples que altres?
#
# > La teva resposta a partir d'aquí:
#
# Per què tenint un dataframe balancejat tenim accuracies diferents? Quina categoria és la mes impactada en el teu cas? Per què?
#
# > La teva resposta a partir d'aquí:
